# %%
import os

if 'main_dir' in globals():
    os.chdir(main_dir)

import pandas as pd
from utils.load_config import load_exp_config, get_value_from_fields, get_df_historical_data
from utils.load_data import (
    get_df_from_datetime_range,
    get_mlruns_info
    )
import numpy as np

# %matplotlib inline

if os.getcwd().endswith("notebooks"):
    main_dir = os.getcwd()
    os.chdir("..")

# %%
os.getuid(), os.getcwd()
# Out:
# (1000, '/home/robosrv/huyhoang/iclr-2025/regelum-playground-iclr')

# %%
DECAY_RATE = 1


# Only used for pivot table
start_datetime_str = "2025-02-17 16-36-58" # Laptop
end_datetime_str = "2025-02-17 16-44-57"
df, actor_df = get_df_from_datetime_range(start_datetime_str, 
                                end_datetime_str, 
                                decay_rate=DECAY_RATE,
                                max_iter=np.inf,
                                validity_check=False,
                                reload=False,
                                # backup_dir="/media/tcc/F89F-5CC1/ICLR/backup-data"
                                )
actor_df.head()
# Out:
#             time  actor_loss  step_id               run_name  \
# 0  1739810299857    0.140214      250  2025-02-17 16-36-58 0
# 1  1739810378424    0.048686      500  2025-02-17 16-36-58 0
# 2  1739810456314    0.798232      750  2025-02-17 16-36-58 0
# 3  1739810532333    0.143160     1000  2025-02-17 16-36-58 0
# 4  1739810610089    0.310694     1250  2025-02-17 16-36-58 0
#
#                                      experiment_path
# 0  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 1  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 2  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 3  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 4  /home/robosrv/huyhoang/iclr-2025/regelum-playg...

# %%
df
# Out:
#      time  running_objective current_value  current_undiscounted_value  \
# 0   0.000           0.500000          None                    0.500000
# 1   0.000           0.000000          None                    0.500000
# 2   0.165           0.000000          None                    0.500000
# 3   0.330           0.000000          None                    0.500000
# 4   0.495           0.000000          None                    0.500000
# ..    ...                ...           ...                         ...
# 16  2.475           0.000000          None                    0.350000
# 17  2.640           0.000000          None                    0.350000
# 18  2.805           0.000000          None                    0.350000
# 19  2.970           0.400000          None                    0.750000
# 20  3.135           0.195522          None                    0.945522
#
#     episode_id  iteration_id task_name  step_id  phase  exploration  ...  \
# 0            1             1  red_cube        1  train        False  ...
# 1            1             1  red_cube        2  train        False  ...
# 2            1             1  red_cube        3  train        False  ...
# 3            1             1  red_cube        4  train        False  ...
# 4            1             1  red_cube        5  train        False  ...
# ..         ...           ...       ...      ...    ...          ...  ...
# 16           1           132       red     1785  train        False  ...
# 17           1           132       red     1786  train        False  ...
# 18           1           132       red     1787  train        False  ...
# 19           1           132       red     1788  train        False  ...
# 20           1           132       red     1789  train        False  ...
#
#    Image pixel 1193 Image pixel 1194 Image pixel 1195  Image pixel 1196  \
# 0          0.290196         0.290196         0.290196          0.290196
# 1          0.290196         0.290196         0.290196          0.290196
# 2          0.290196         0.290196         0.290196          0.290196
# 3          0.290196         0.290196         0.290196          0.290196
# 4          0.290196         0.290196         0.290196          0.290196
# ..              ...              ...              ...               ...
# 16         0.423529         0.423529         0.423529          0.423529
# 17         0.423529         0.423529         0.423529          0.423529
# 18         0.423529         0.423529         0.423529          0.423529
# 19         0.423529         0.423529         0.423529          0.423529
# 20         0.423529         0.423529         0.423529          0.423529
#
#     Image pixel 1197  Image pixel 1198  Image pixel 1199  \
# 0           0.290196          0.290196          0.290196
# 1           0.290196          0.290196          0.290196
# 2           0.290196          0.290196          0.290196
# 3           0.290196          0.290196          0.290196
# 4           0.290196          0.290196          0.290196
# ..               ...               ...               ...
# 16          0.423529          0.423529          0.423529
# 17          0.423529          0.423529          0.423529
# 18          0.423529          0.423529          0.423529
# 19          0.423529          0.423529          0.423529
# 20          0.423529          0.423529          0.423529
#
#                                         absolute_path  \
# 0   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 1   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 2   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 3   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 4   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# ..                                                ...
# 16  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 17  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 18  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 19  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 20  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
#
#                                            exp_config  \
# 0   {'policy': {'_target_': 'src.policy.PendulumPo...
# 1   {'policy': {'_target_': 'src.policy.PendulumPo...
# 2   {'policy': {'_target_': 'src.policy.PendulumPo...
# 3   {'policy': {'_target_': 'src.policy.PendulumPo...
# 4   {'policy': {'_target_': 'src.policy.PendulumPo...
# ..                                                ...
# 16  {'policy': {'_target_': 'src.policy.PendulumPo...
# 17  {'policy': {'_target_': 'src.policy.PendulumPo...
# 18  {'policy': {'_target_': 'src.policy.PendulumPo...
# 19  {'policy': {'_target_': 'src.policy.PendulumPo...
# 20  {'policy': {'_target_': 'src.policy.PendulumPo...
#
#                                       experiment_path
# 0   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 1   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 2   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 3   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 4   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# ..                                                ...
# 16  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 17  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 18  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 19  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 20  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
#
# [7468 rows x 1216 columns]

# %%
exp_config = df.exp_config.values[0]
df = df.reindex()
def extract_columns(row):
    scenario = row.exp_config["scenario"]["_target_"].split(".")[-1]
    controller = "PPO" if "ppo" in scenario.lower() else "unknown"
    category = row.exp_config["scenario"]["env"]
    return category, controller
    
    # return pd.Series(data=[category, controller, is_reset_buffer, buffer_size], 
    #                  index=["category", "controller", "is_reset_buffer", "buffer_size"])

tmp = df.apply(extract_columns, axis=1, result_type='expand')
# tmp = df.exp_config.apply(extract_columns)
tmp.columns = ["category", "controller"]
df = pd.concat([df, tmp], axis=1)

df = df.sort_values(["experiment_path", "iteration_id", "step_id"])
df["trained_task"] = df.apply(lambda row: row.task_name if row.phase == "train" else pd.NA, axis=1)
df["trained_task"] = df.trained_task.fillna(method='ffill')
df
# Out:
# /tmp/ipykernel_3889/2523547596.py:19: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["trained_task"] = df.trained_task.fillna(method='ffill')
#      time  running_objective current_value  current_undiscounted_value  \
# 0   0.000           0.500000          None                    0.500000
# 1   0.000           0.000000          None                    0.500000
# 2   0.165           0.000000          None                    0.500000
# 3   0.330           0.000000          None                    0.500000
# 4   0.495           0.000000          None                    0.500000
# ..    ...                ...           ...                         ...
# 16  2.475           0.000000          None                    0.350000
# 17  2.640           0.000000          None                    0.350000
# 18  2.805           0.000000          None                    0.350000
# 19  2.970           0.400000          None                    0.750000
# 20  3.135           0.195522          None                    0.945522
#
#     episode_id  iteration_id task_name  step_id  phase  exploration  ...  \
# 0            1             1  red_cube        1  train        False  ...
# 1            1             1  red_cube        2  train        False  ...
# 2            1             1  red_cube        3  train        False  ...
# 3            1             1  red_cube        4  train        False  ...
# 4            1             1  red_cube        5  train        False  ...
# ..         ...           ...       ...      ...    ...          ...  ...
# 16           1           132       red     1785  train        False  ...
# 17           1           132       red     1786  train        False  ...
# 18           1           132       red     1787  train        False  ...
# 19           1           132       red     1788  train        False  ...
# 20           1           132       red     1789  train        False  ...
#
#    Image pixel 1196 Image pixel 1197 Image pixel 1198  Image pixel 1199  \
# 0          0.290196         0.290196         0.290196          0.290196
# 1          0.290196         0.290196         0.290196          0.290196
# 2          0.290196         0.290196         0.290196          0.290196
# 3          0.290196         0.290196         0.290196          0.290196
# 4          0.290196         0.290196         0.290196          0.290196
# ..              ...              ...              ...               ...
# 16         0.423529         0.423529         0.423529          0.423529
# 17         0.423529         0.423529         0.423529          0.423529
# 18         0.423529         0.423529         0.423529          0.423529
# 19         0.423529         0.423529         0.423529          0.423529
# 20         0.423529         0.423529         0.423529          0.423529
#
#                                         absolute_path  \
# 0   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 1   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 2   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 3   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 4   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# ..                                                ...
# 16  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 17  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 18  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 19  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
# 20  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
#
#                                            exp_config  \
# 0   {'policy': {'_target_': 'src.policy.PendulumPo...
# 1   {'policy': {'_target_': 'src.policy.PendulumPo...
# 2   {'policy': {'_target_': 'src.policy.PendulumPo...
# 3   {'policy': {'_target_': 'src.policy.PendulumPo...
# 4   {'policy': {'_target_': 'src.policy.PendulumPo...
# ..                                                ...
# 16  {'policy': {'_target_': 'src.policy.PendulumPo...
# 17  {'policy': {'_target_': 'src.policy.PendulumPo...
# 18  {'policy': {'_target_': 'src.policy.PendulumPo...
# 19  {'policy': {'_target_': 'src.policy.PendulumPo...
# 20  {'policy': {'_target_': 'src.policy.PendulumPo...
#
#                                       experiment_path       category  \
# 0   /home/robosrv/huyhoang/iclr-2025/regelum-playg...   RobotPursuit
# 1   /home/robosrv/huyhoang/iclr-2025/regelum-playg...   RobotPursuit
# 2   /home/robosrv/huyhoang/iclr-2025/regelum-playg...   RobotPursuit
# 3   /home/robosrv/huyhoang/iclr-2025/regelum-playg...   RobotPursuit
# 4   /home/robosrv/huyhoang/iclr-2025/regelum-playg...   RobotPursuit
# ..                                                ...            ...
# 16  /home/robosrv/huyhoang/iclr-2025/regelum-playg...  PushingObject
# 17  /home/robosrv/huyhoang/iclr-2025/regelum-playg...  PushingObject
# 18  /home/robosrv/huyhoang/iclr-2025/regelum-playg...  PushingObject
# 19  /home/robosrv/huyhoang/iclr-2025/regelum-playg...  PushingObject
# 20  /home/robosrv/huyhoang/iclr-2025/regelum-playg...  PushingObject
#
#     controller  trained_task
# 0          PPO      red_cube
# 1          PPO      red_cube
# 2          PPO      red_cube
# 3          PPO      red_cube
# 4          PPO      red_cube
# ..         ...           ...
# 16         PPO           red
# 17         PPO           red
# 18         PPO           red
# 19         PPO           red
# 20         PPO           red
#
# [7468 rows x 1219 columns]

# %%
[c for c in df.columns if "pos" in c]
# Out:
# ['robot_position']

# %%
pd.Series(tmp.iloc[0], index=["category", "controller"])
# Out:
# category      RobotPursuit
# controller             PPO
# Name: 0, dtype: object

# %%
############################### Robot Pursuit is misisng ###############################
# group_df = df.groupby(["controller", "category", "task_name", "is_reset_buffer"]).last()
group_df = df.groupby(["controller", "category"]).last()
# group_df = df.groupby(["controller"]).last()
group_df
# Out:
#                            time  running_objective current_value  \
# controller category
# PPO        LineFollowing  4.620           0.489796          None
#            PushingObject  3.135           0.195522          None
#            RobotPursuit   0.660          -1.000000          None
#
#                           current_undiscounted_value  episode_id  \
# controller category
# PPO        LineFollowing                   20.000000           1
#            PushingObject                    0.945522           1
#            RobotPursuit                    -0.880000           1
#
#                           iteration_id   task_name  step_id  phase  \
# controller category
# PPO        LineFollowing           100  circle_red     2563  train
#            PushingObject           132         red     1789  train
#            RobotPursuit            157    red_cube     3116  train
#
#                           exploration  ... Image pixel 1194 Image pixel 1195  \
# controller category                    ...
# PPO        LineFollowing        False  ...              NaN              NaN
#            PushingObject        False  ...         0.423529         0.423529
#            RobotPursuit         False  ...         0.290196         0.290196
#
#                          Image pixel 1196  Image pixel 1197  Image pixel 1198  \
# controller category
# PPO        LineFollowing              NaN               NaN               NaN
#            PushingObject         0.423529          0.423529          0.423529
#            RobotPursuit          0.290196          0.290196          0.290196
#
#                           Image pixel 1199  \
# controller category
# PPO        LineFollowing               NaN
#            PushingObject          0.423529
#            RobotPursuit           0.290196
#
#                                                               absolute_path  \
# controller category
# PPO        LineFollowing  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
#            PushingObject  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
#            RobotPursuit   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
#
#                                                                  exp_config  \
# controller category
# PPO        LineFollowing  {'policy': {'_target_': 'src.policy.PendulumPo...
#            PushingObject  {'policy': {'_target_': 'src.policy.PendulumPo...
#            RobotPursuit   {'policy': {'_target_': 'src.policy.PendulumPo...
#
#                                                             experiment_path  \
# controller category
# PPO        LineFollowing  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
#            PushingObject  /home/robosrv/huyhoang/iclr-2025/regelum-playg...
#            RobotPursuit   /home/robosrv/huyhoang/iclr-2025/regelum-playg...
#
#                           trained_task
# controller category
# PPO        LineFollowing    circle_red
#            PushingObject           red
#            RobotPursuit       red_cube
#
# [3 rows x 1217 columns]

# %%
group_df.index.names, group_df.index[0]
# Out:
# (FrozenList(['controller', 'category']), ('PPO', 'LineFollowing'))

# %%
"\t".join([f"{a}:{b}" for a, b in list(zip(group_df.index.names, group_df.index[0]))])
# list(zip(group_df.index.names, group_df.index[0]))
group_df.index
# Out:
# MultiIndex([('PPO', 'LineFollowing'),
#             ('PPO', 'PushingObject'),
#             ('PPO',  'RobotPursuit')],
#            names=['controller', 'category'])

# %%
df = df.reset_index().set_index(group_df.index.names)
tmp_df = df.loc[group_df.index[0]]
# Out:
# /tmp/ipykernel_3889/2743105663.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   tmp_df = df.loc[group_df.index[0]]

# %%
from matplotlib import rc
# rc('font',**{'family':'sans-serif','sans-serif':['Helvelica']})
# for Palatino and other serif fonts use:
# rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=False)

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
matplotlib.__version__
# Out:
# /home/robosrv/huyhoang/iclr-2025/regelum-playground-iclr/venv/lib/python3.11/site-packages/matplotlib/mpl-data/matplotlibrc
# '3.9.2'

# %% [markdown]
# # Graph

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": 20
})
# import matplotlib
# %matplotlib inline

def interpolate(X_, Y_):
    N_SAMPLE_INTER=1000

    degree = 30
    coeffs = np.polyfit(X_, Y_, degree)
    X_ = np.linspace(X_.min(), X_.max(), N_SAMPLE_INTER)
    Y_ = np.polyval(coeffs, X_)

    return X_, Y_

def plot_learning_curve(index, index_names, df, title="Learning curve", ax=None, use_interpolate=False):
    if ax is None:
        fig, ax = plt.subplots(figsize=(10,3))

    df = df.reset_index().set_index(index_names)
    df["learning_starts"] = 250
    tmp_df = df.loc[index]

    # Filter exploration actions
    tmp_df = tmp_df.loc[:, ["iteration_id", "step_id", "task_name", "current_undiscounted_value", "learning_starts", "phase"]]
    tmp_df = tmp_df[np.invert(np.logical_and(tmp_df.phase == "train", tmp_df.step_id <= tmp_df.learning_starts))]
    tmp_group_df = tmp_df.groupby("iteration_id")

    tmp_group_df = tmp_group_df.aggregate({
        "current_undiscounted_value": "last", 
        "task_name": "last",
        "step_id": "last"
        })
    
    # Re-assign index for ploting
    tmp_group_df = tmp_group_df.reset_index()
    tmp_group_df.iteration_id = tmp_group_df.reset_index().index

    if not use_interpolate:
        tmp_group_df = tmp_group_df.set_index("iteration_id")
        tmp_group_df.plot(y="current_undiscounted_value", ax=ax, color="purple")
    else:
        ax.plot(*interpolate(tmp_group_df.iteration_id, tmp_group_df.current_undiscounted_value), color="purple")
        

    colors = ["red", "blue", "green", "yellow"]
    for t in tmp_group_df.task_name.unique():
        for c in colors:
            if c in t.lower():
                break

        tmp = tmp_group_df.reset_index().set_index("task_name").loc[t]
        ax.axvspan(tmp.iteration_id.values[0], tmp.iteration_id.values[-1], alpha=0.6, color=c)

    ax.set_xlabel('Episode')
    ax.set_ylabel('Accumulated reward per episode')
    ax.set_title(
        f'{title}\n' + 
        "   ".join([f"{a}: {b}" for a, b in list(zip(index_names, index))])
    )
    legend = ax.legend()
    legend.remove()

    return "_".join([f"{a}_{b}" for a, b in list(zip(index_names, index))]) + "_interp_{}".format(1 if use_interpolate else 0)


for id in group_df.index:
    for interp in [True, False]:
        fig, ax = plt.subplots(2, 1, figsize=(12, 10))
        title = plot_learning_curve(id, 
                                    group_df.index.names, 
                                    df[df.phase=="train"], 
                                    ax=ax[0],
                                    use_interpolate=interp)
        
        actor_df["steps"] = [100 * i for i in range(len(actor_df))]
        actor_df[actor_df.experiment_path == df.experiment_path.values[0]].plot(x="steps", y="actor_loss", ax=ax[1])
        ax[1].set_title("Actor loss")
        ax[1].set_ylabel("Logarithmic loss")
        ax[1].set_xlabel("Step")
        ax[1].legend().remove()
        ax[1].grid()
        # plot_learning_curve(group_df.index[1], group_df.index.names, df)
        # plot_learning_curve(('SAC', 'LineFollowing', True), group_df.index.names, df)
        # plot_learning_curve(('TD3', 'LineFollowing', False), group_df.index.names, df)
        # plt.show()
        plt.tight_layout()
        os.makedirs("./media", exist_ok=True)
        fig.savefig("./media/{}.pdf".format(title))
# Out:
# /tmp/ipykernel_3889/1418966543.py:27: PerformanceWarning: indexing past lexsort depth may impact performance.
#   tmp_df = df.loc[index]
# /tmp/ipykernel_3889/1418966543.py:15: RankWarning: Polyfit may be poorly conditioned
#   coeffs = np.polyfit(X_, Y_, degree)
# /tmp/ipykernel_3889/1418966543.py:66: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   legend = ax.legend()
# /tmp/ipykernel_3889/1418966543.py:27: PerformanceWarning: indexing past lexsort depth may impact performance.
#   tmp_df = df.loc[index]
# /tmp/ipykernel_3889/1418966543.py:27: PerformanceWarning: indexing past lexsort depth may impact performance.
#   tmp_df = df.loc[index]
# /tmp/ipykernel_3889/1418966543.py:15: RankWarning: Polyfit may be poorly conditioned
#   coeffs = np.polyfit(X_, Y_, degree)
# /tmp/ipykernel_3889/1418966543.py:66: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   legend = ax.legend()
# /tmp/ipykernel_3889/1418966543.py:27: PerformanceWarning: indexing past lexsort depth may impact performance.
#   tmp_df = df.loc[index]
# /tmp/ipykernel_3889/1418966543.py:27: PerformanceWarning: indexing past lexsort depth may impact performance.
#   tmp_df = df.loc[index]
# /tmp/ipykernel_3889/1418966543.py:15: RankWarning: Polyfit may be poorly conditioned
#   coeffs = np.polyfit(X_, Y_, degree)
# /tmp/ipykernel_3889/1418966543.py:66: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   legend = ax.legend()
# /tmp/ipykernel_3889/1418966543.py:27: PerformanceWarning: indexing past lexsort depth may impact performance.
#   tmp_df = df.loc[index]

# %%
df[df.phase=="train"].set_index("iteration_id").current_undiscounted_value.values[-30:]
# Out:
# array([21.83673469, 22.81632653, 23.75510204, 24.73469388, 25.67346939,
#        26.65306122, 27.63265306, 28.57142857,  0.73469388,  1.59183673,
#         2.57142857,  3.51020408,  4.44897959,  5.42857143,  6.40816327,
#         7.3877551 ,  8.36734694,  9.34693878, 10.32653061, 11.30612245,
#        12.24489796, 13.2244898 , 14.20408163, 15.18367347, 16.16326531,
#        17.14285714, 18.12244898, 19.10204082, 20.08163265, 21.06122449])

# %%
df = df.reset_index()
df[df.iteration_id==1]
# Out:
#    controller       category  buffer_size  index   time  running_objective  \
# 0         SAC  LineFollowing        20000      0  0.000           0.489796
# 1         SAC  LineFollowing        20000      1  0.000           0.285714
# 2         SAC  LineFollowing        20000      2  0.165           0.244898
# 3         SAC  LineFollowing        20000      3  0.330           0.244898
# 4         SAC  LineFollowing        20000      4  0.495           0.163265
# 5         SAC  LineFollowing        20000      5  0.660           0.204082
# 6         SAC  LineFollowing        20000      6  0.825           0.081633
# 7         SAC  LineFollowing        20000      7  0.990           0.122449
# 8         SAC  LineFollowing        20000      8  1.155           0.122449
# 9         SAC  LineFollowing        20000      9  1.320           0.122449
# 10        SAC  LineFollowing        20000     10  1.485           0.081633
# 11        SAC  LineFollowing        20000     11  1.650           0.122449
# 12        SAC  LineFollowing        20000     12  1.815           0.081633
# 13        SAC  LineFollowing        20000     13  1.980           0.122449
# 14        SAC  LineFollowing        20000     14  2.145           0.122449
# 15        SAC  LineFollowing        20000     15  2.310           0.122449
# 16        SAC  LineFollowing        20000     16  2.475           0.163265
# 17        SAC  LineFollowing        20000     17  2.640           0.204082
# 18        SAC  LineFollowing        20000     18  2.805           0.244898
# 19        SAC  LineFollowing        20000     19  2.970           0.204082
# 20        SAC  LineFollowing        20000     20  3.135           0.204082
# 21        SAC  LineFollowing        20000     21  3.300           0.244898
# 22        SAC  LineFollowing        20000     22  3.465           0.326531
# 23        SAC  LineFollowing        20000     23  3.630           0.408163
# 24        SAC  LineFollowing        20000     24  3.795           0.448980
# 25        SAC  LineFollowing        20000     25  3.960           0.530612
# 26        SAC  LineFollowing        20000     26  4.125           0.530612
# 27        SAC  LineFollowing        20000     27  4.290           0.571429
# 28        SAC  LineFollowing        20000     28  4.455           0.612245
# 29        SAC  LineFollowing        20000     29  4.620           0.653061
#
#    current_value  current_undiscounted_value  episode_id  iteration_id  ...  \
# 0           None                    0.489796           1             1  ...
# 1           None                    0.775510           1             1  ...
# 2           None                    1.020408           1             1  ...
# 3           None                    1.265306           1             1  ...
# 4           None                    1.428571           1             1  ...
# 5           None                    1.632653           1             1  ...
# 6           None                    1.714286           1             1  ...
# 7           None                    1.836735           1             1  ...
# 8           None                    1.959184           1             1  ...
# 9           None                    2.081633           1             1  ...
# 10          None                    2.163265           1             1  ...
# 11          None                    2.285714           1             1  ...
# 12          None                    2.367347           1             1  ...
# 13          None                    2.489796           1             1  ...
# 14          None                    2.612245           1             1  ...
# 15          None                    2.734694           1             1  ...
# 16          None                    2.897959           1             1  ...
# 17          None                    3.102041           1             1  ...
# 18          None                    3.346939           1             1  ...
# 19          None                    3.551020           1             1  ...
# 20          None                    3.755102           1             1  ...
# 21          None                    4.000000           1             1  ...
# 22          None                    4.326531           1             1  ...
# 23          None                    4.734694           1             1  ...
# 24          None                    5.183673           1             1  ...
# 25          None                    5.714286           1             1  ...
# 26          None                    6.244898           1             1  ...
# 27          None                    6.816327           1             1  ...
# 28          None                    7.428571           1             1  ...
# 29          None                    8.081633           1             1  ...
#
#    Image pixel 296  Image pixel 297 Image pixel 298  Image pixel 299  \
# 0         0.000000         0.466667        0.000000         0.000000
# 1         0.000000         0.466667        0.000000         0.000000
# 2         0.000000         0.466667        0.000000         0.000000
# 3         0.000000         0.458824        0.000000         0.000000
# 4         0.000000         0.462745        0.000000         0.000000
# 5         0.000000         0.458824        0.000000         0.000000
# 6         0.000000         0.462745        0.000000         0.000000
# 7         0.000000         0.458824        0.000000         0.000000
# 8         0.000000         0.454902        0.000000         0.000000
# 9         0.000000         0.454902        0.000000         0.000000
# 10        0.000000         0.454902        0.000000         0.000000
# 11        0.000000         0.450980        0.000000         0.000000
# 12        0.000000         0.450980        0.000000         0.000000
# 13        0.000000         0.447059        0.000000         0.000000
# 14        0.000000         0.450980        0.000000         0.000000
# 15        0.000000         0.450980        0.000000         0.000000
# 16        0.000000         0.447059        0.000000         0.000000
# 17        0.000000         0.450980        0.000000         0.000000
# 18        0.000000         0.447059        0.000000         0.000000
# 19        0.000000         0.450980        0.000000         0.000000
# 20        0.000000         0.447059        0.000000         0.000000
# 21        0.000000         0.443137        0.000000         0.000000
# 22        0.000000         0.443137        0.000000         0.000000
# 23        0.003922         0.439216        0.003922         0.003922
# 24        0.003922         0.439216        0.003922         0.003922
# 25        0.000000         0.443137        0.000000         0.000000
# 26        0.000000         0.447059        0.000000         0.000000
# 27        0.000000         0.447059        0.000000         0.000000
# 28        0.000000         0.443137        0.000000         0.000000
# 29        0.003922         0.439216        0.003922         0.003922
#
#                                         absolute_path  \
# 0   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 1   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 2   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 3   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 4   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 5   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 6   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 7   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 8   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 9   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 10  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 11  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 12  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 13  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 14  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 15  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 16  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 17  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 18  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 19  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 20  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 21  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 22  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 23  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 24  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 25  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 26  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 27  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 28  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 29  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
#                                            exp_config  \
# 0   {'policy': {'_target_': 'src.policy.PendulumPo...
# 1   {'policy': {'_target_': 'src.policy.PendulumPo...
# 2   {'policy': {'_target_': 'src.policy.PendulumPo...
# 3   {'policy': {'_target_': 'src.policy.PendulumPo...
# 4   {'policy': {'_target_': 'src.policy.PendulumPo...
# 5   {'policy': {'_target_': 'src.policy.PendulumPo...
# 6   {'policy': {'_target_': 'src.policy.PendulumPo...
# 7   {'policy': {'_target_': 'src.policy.PendulumPo...
# 8   {'policy': {'_target_': 'src.policy.PendulumPo...
# 9   {'policy': {'_target_': 'src.policy.PendulumPo...
# 10  {'policy': {'_target_': 'src.policy.PendulumPo...
# 11  {'policy': {'_target_': 'src.policy.PendulumPo...
# 12  {'policy': {'_target_': 'src.policy.PendulumPo...
# 13  {'policy': {'_target_': 'src.policy.PendulumPo...
# 14  {'policy': {'_target_': 'src.policy.PendulumPo...
# 15  {'policy': {'_target_': 'src.policy.PendulumPo...
# 16  {'policy': {'_target_': 'src.policy.PendulumPo...
# 17  {'policy': {'_target_': 'src.policy.PendulumPo...
# 18  {'policy': {'_target_': 'src.policy.PendulumPo...
# 19  {'policy': {'_target_': 'src.policy.PendulumPo...
# 20  {'policy': {'_target_': 'src.policy.PendulumPo...
# 21  {'policy': {'_target_': 'src.policy.PendulumPo...
# 22  {'policy': {'_target_': 'src.policy.PendulumPo...
# 23  {'policy': {'_target_': 'src.policy.PendulumPo...
# 24  {'policy': {'_target_': 'src.policy.PendulumPo...
# 25  {'policy': {'_target_': 'src.policy.PendulumPo...
# 26  {'policy': {'_target_': 'src.policy.PendulumPo...
# 27  {'policy': {'_target_': 'src.policy.PendulumPo...
# 28  {'policy': {'_target_': 'src.policy.PendulumPo...
# 29  {'policy': {'_target_': 'src.policy.PendulumPo...
#
#                                       experiment_path  is_reset_buffer  \
# 0   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 1   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 2   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 3   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 4   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 5   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 6   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 7   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 8   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 9   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 10  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 11  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 12  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 13  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 14  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 15  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 16  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 17  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 18  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 19  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 20  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 21  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 22  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 23  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 24  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 25  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 26  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 27  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 28  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
# 29  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...            False
#
#     learning_starts  trained_task
# 0               250    circle_red
# 1               250    circle_red
# 2               250    circle_red
# 3               250    circle_red
# 4               250    circle_red
# 5               250    circle_red
# 6               250    circle_red
# 7               250    circle_red
# 8               250    circle_red
# 9               250    circle_red
# 10              250    circle_red
# 11              250    circle_red
# 12              250    circle_red
# 13              250    circle_red
# 14              250    circle_red
# 15              250    circle_red
# 16              250    circle_red
# 17              250    circle_red
# 18              250    circle_red
# 19              250    circle_red
# 20              250    circle_red
# 21              250    circle_red
# 22              250    circle_red
# 23              250    circle_red
# 24              250    circle_red
# 25              250    circle_red
# 26              250    circle_red
# 27              250    circle_red
# 28              250    circle_red
# 29              250    circle_red
#
# [30 rows x 323 columns]

# %%
df.running_objective.describe()
# Out:
# count    29000.000000
# mean         0.683011
# std          0.348645
# min         -1.000000
# 25%          0.489796
# 50%          0.857143
# 75%          0.938776
# max          0.979592
# Name: running_objective, dtype: float64

# %%
def postprocess_linefollowing(df):
    if not df.index.is_integer():
        df = df.reset_index()

    df["catch_the_line"] = df.running_objective.apply(lambda x: x > 0.7)
    return df

# %%
df = postprocess_linefollowing(df)

analyse_group_df = df[df.phase == "eval"].reset_index().groupby(["task_name", "iteration_id"])

if "catch_the_line" in df.columns:
    agg = dict.fromkeys(df.columns.difference(['catch_the_line', "task_name", "iteration_id"]), 'last')
    agg['catch_the_line'] = 'sum'

    analyse_group_df = analyse_group_df.agg(agg)
else:
    analyse_group_df = analyse_group_df.last()

analyse_group_df
# Out:
# /tmp/ipykernel_1173383/3626384526.py:2: FutureWarning: RangeIndex.is_integer is deprecated. Use pandas.api.types.is_integer_dtype instead.
#   if not df.index.is_integer():
#                             Angular Velocity [rad/s]  Image pixel 0  \
# task_name     iteration_id
# circle_blue   445                          -0.529903       0.000000
#               446                          -0.435675       0.000000
#               447                          -0.402190       0.000000
#               448                          -0.452046       0.000000
#               449                          -0.469835       0.000000
# ...                                              ...            ...
# circle_yellow 1033                          1.184987       0.470588
#               1034                          1.386925       0.470588
#               1035                          1.324670       0.470588
#               1036                          0.104607       0.470588
#               1037                          1.309178       0.470588
#
#                             Image pixel 1  Image pixel 10  Image pixel 100  \
# task_name     iteration_id
# circle_blue   445                0.000000        0.000000              0.0
#               446                0.000000        0.000000              0.0
#               447                0.000000        0.000000              0.0
#               448                0.000000        0.000000              0.0
#               449                0.000000        0.000000              0.0
# ...                                   ...             ...              ...
# circle_yellow 1033               0.470588        0.470588              0.0
#               1034               0.470588        0.470588              0.0
#               1035               0.470588        0.470588              0.0
#               1036               0.470588        0.470588              0.0
#               1037               0.470588        0.470588              0.0
#
#                             Image pixel 101  Image pixel 102  Image pixel 103  \
# task_name     iteration_id
# circle_blue   445                       0.0              0.0              0.0
#               446                       0.0              0.0              0.0
#               447                       0.0              0.0              0.0
#               448                       0.0              0.0              0.0
#               449                       0.0              0.0              0.0
# ...                                     ...              ...              ...
# circle_yellow 1033                      0.0              0.0              0.0
#               1034                      0.0              0.0              0.0
#               1035                      0.0              0.0              0.0
#               1036                      0.0              0.0              0.0
#               1037                      0.0              0.0              0.0
#
#                             Image pixel 104  Image pixel 105  ...  index  \
# task_name     iteration_id                                    ...
# circle_blue   445                       0.0              0.0  ...     29
#               446                       0.0              0.0  ...     29
#               447                       0.0              0.0  ...     29
#               448                       0.0              0.0  ...     29
#               449                       0.0              0.0  ...     29
# ...                                     ...              ...  ...    ...
# circle_yellow 1033                      0.0              0.0  ...     29
#               1034                      0.0              0.0  ...     29
#               1035                      0.0              0.0  ...     29
#               1036                      0.0              0.0  ...     29
#               1037                      0.0              0.0  ...     29
#
#                             is_reset_buffer  learning_starts  phase  \
# task_name     iteration_id
# circle_blue   445                     False              250   eval
#               446                     False              250   eval
#               447                     False              250   eval
#               448                     False              250   eval
#               449                     False              250   eval
# ...                                     ...              ...    ...
# circle_yellow 1033                    False              250   eval
#               1034                    False              250   eval
#               1035                    False              250   eval
#               1036                    False              250   eval
#               1037                    False              250   eval
#
#                                                                robot_position  \
# task_name     iteration_id
# circle_blue   445           [2.9695645806418656e-10, -1.3788157795997734e-...
#               446           [2.917994792084919e-10, -1.3556942952211617e-1...
#               447           [2.9184969393613113e-10, -1.355876800490104e-1...
#               448           [2.918869772524808e-10, -1.3555600202165533e-1...
#               449           [2.969002594150638e-10, -1.3789295261325126e-1...
# ...                                                                       ...
# circle_yellow 1033          [20.000000000327187, 1.5155163864055412e-10, -...
#               1034          [20.000000000294552, 1.3631302643485856e-10, -...
#               1035          [20.00000000029674, -1.3800517155552784e-10, -...
#               1036          [20.000000000292065, 1.3517903784689623e-10, -...
#               1037          [20.000000000324647, 1.5038248977969635e-10, -...
#
#                             running_objective  step_id   time   trained_task  \
# task_name     iteration_id
# circle_blue   445                    0.897959       29  4.620    circle_blue
#               446                    0.897959       59  4.620    circle_blue
#               447                    0.897959       89  4.620    circle_blue
#               448                    0.897959      119  4.620    circle_blue
#               449                    0.897959      149  4.620    circle_blue
# ...                                       ...      ...    ...            ...
# circle_yellow 1033                   0.938776      779  4.653  circle_yellow
#               1034                   0.938776      809  4.620  circle_yellow
#               1035                   0.938776      839  4.620  circle_yellow
#               1036                   0.979592      869  4.620  circle_yellow
#               1037                   0.938776      899  4.620  circle_yellow
#
#                             catch_the_line
# task_name     iteration_id
# circle_blue   445                       23
#               446                       23
#               447                       23
#               448                       23
#               449                       23
# ...                                    ...
# circle_yellow 1033                      30
#               1034                      30
#               1035                      30
#               1036                      23
#               1037                      30
#
# [300 rows x 322 columns]

# %% [markdown]
# # Evaluation

# %%
def experiment_sort_index(index):
    print(index)
    if index.name == "category":
        category_list = ["PushingObject", "LineFollowing", "RobotPursuit"]
    #     return [category_list.index(n) for n in index]nt(index)
    # if index.name == "category":
    #     category_list = ["PushingObject", "LineFollowing", "RobotPursuit"]
    #     return [category_list.index(n) for n in index]
    
    if index.name in ["trained_task", "task_name"]:
        lf_list = ["circle_red", "circle_blue", "circle_green", "circle_yellow"]
        rp_list = ["red_cube", "green_capsule", "blue_sphere", "yellow_cylinder"]
        po_list = ["red", "blue", "green", "yellow"]

        common_list = lf_list + rp_list + po_list
        return [common_list.index(n) for n in index]
    
    return [a for a in index]

# %%
df = postprocess_linefollowing(df)

def pivot_success(df):
    if "eval" in df.phase.unique():
        analyse_group_df = df[df.phase == "eval"].reset_index().groupby(["task_name", "iteration_id"])

        if "catch_the_line" in df.columns:
            agg = dict.fromkeys(df.columns.difference(['catch_the_line', "task_name", "iteration_id"]), 'last')
            agg['catch_the_line'] = 'sum'

            analyse_group_df = analyse_group_df.agg(agg)
        else:
            analyse_group_df = analyse_group_df.last()

        def is_solved_task(row):
            if row.category == "LineFollowing":
                return row.catch_the_line > 20

            if row.category == "PushingObject":
                if row.task_name in ["blue", "yellow"]:
                    return row.running_objective == 10
                
                if row.task_name in ["red", "green"]:
                    return row.running_objective != -10

            if row.category == "RobotPursuit":
                return row.running_objective == 10
            
            return False

        def aggregate_function(series):
            sucess = np.sum(series)
            total = series.count()
            return "{:02.0f} / {:02.0f} = {:03.2f}".format(sucess, total, np.round(sucess / total, 2))

        analyse_group_df = analyse_group_df.reset_index()
        analyse_group_df["completion"] = analyse_group_df.apply(is_solved_task, axis=1)

        analyse_group_df.buffer_size = analyse_group_df.buffer_size.apply(lambda x: 20000 if x == 25000 else x)
        # analyse_group_df = analyse_group_df.set_index(['controller', 'category', 'buffer_size'])

        pivot_table = pd.pivot_table(
            analyse_group_df.reset_index(), 
            columns=['controller', 'buffer_size', 'trained_task'],
            index=["category", "task_name"], 
            values="completion", aggfunc=aggregate_function
        )
        
        pivot_table = pivot_table.sort_index(key=experiment_sort_index, ascending=True).sort_index(key=experiment_sort_index, axis=1, ascending=True)
    else:
        pivot_table = None
    
    return pivot_table

pivot_success(df[df.category == "LineFollowing"])
pivot_success(df).to_latex()
# Out:
# /tmp/ipykernel_1173383/3626384526.py:2: FutureWarning: RangeIndex.is_integer is deprecated. Use pandas.api.types.is_integer_dtype instead.
#   if not df.index.is_integer():
# Index(['LineFollowing', 'LineFollowing', 'LineFollowing', 'LineFollowing'], dtype='object', name='category')
# Index(['circle_blue', 'circle_green', 'circle_red', 'circle_yellow'], dtype='object', name='task_name')
# Index(['SAC', 'SAC', 'SAC', 'SAC'], dtype='object', name='controller')
# Index([20000, 20000, 20000, 20000], dtype='int64', name='buffer_size')
# Index(['circle_blue', 'circle_green', 'circle_red', 'circle_yellow'], dtype='object', name='trained_task')
# Index(['LineFollowing', 'LineFollowing', 'LineFollowing', 'LineFollowing'], dtype='object', name='category')
# Index(['circle_blue', 'circle_green', 'circle_red', 'circle_yellow'], dtype='object', name='task_name')
# Index(['SAC', 'SAC', 'SAC', 'SAC'], dtype='object', name='controller')
# Index([20000, 20000, 20000, 20000], dtype='int64', name='buffer_size')
# Index(['circle_blue', 'circle_green', 'circle_red', 'circle_yellow'], dtype='object', name='trained_task')
# '\\begin{tabular}{llllll}\n\\toprule\n & controller & \\multicolumn{4}{r}{SAC} \\\\\n & buffer_size & \\multicolumn{4}{r}{20000} \\\\\n & trained_task & circle_red & circle_blue & circle_green & circle_yellow \\\\\ncategory & task_name &  &  &  &  \\\\\n\\midrule\n\\multirow[t]{4}{*}{LineFollowing} & circle_red & 30 / 30 = 1.00 & 30 / 30 = 1.00 & 30 / 30 = 1.00 & 30 / 30 = 1.00 \\\\\n & circle_blue & NaN & 30 / 30 = 1.00 & 30 / 30 = 1.00 & 30 / 30 = 1.00 \\\\\n & circle_green & NaN & NaN & 13 / 30 = 0.43 & 30 / 30 = 1.00 \\\\\n & circle_yellow & NaN & NaN & NaN & 30 / 30 = 1.00 \\\\\n\\cline{1-6}\n\\bottomrule\n\\end{tabular}\n'

# %%
pivot_success(df[df.category == "RobotPursuit"])

# %%
def pivot_avg(df):
    if "eval" in df.phase.unique():
        analyse_group_df = df[df.phase == "eval"].reset_index().groupby(["task_name", "iteration_id"])

        if "catch_the_line" in df.columns:
            agg = dict.fromkeys(df.columns.difference(['catch_the_line', "task_name", "iteration_id"]), 'last')
            agg['catch_the_line'] = 'sum'

            analyse_group_df = analyse_group_df.agg(agg)
        else:
            analyse_group_df = analyse_group_df.last()

        def is_solved_task(row):
            if row.category == "LineFollowing":
                return row.catch_the_line > 20

            if row.category == "PushingObject":
                if row.task_name in ["blue", "yellow"]:
                    return row.running_objective == 10
                
                if row.task_name in ["red", "green"]:
                    return row.running_objective != -10

            if row.category == "RobotPursuit":
                return row.running_objective == 10
            
            return False

        def aggregate_function(series):
            sucess = np.sum(series)
            total = series.count()
            return "{:02.0f} / {:02.0f} = {:03.2f}".format(sucess, total, np.round(sucess / total, 2))

        analyse_group_df = analyse_group_df.reset_index()
        analyse_group_df["completion"] = analyse_group_df.apply(is_solved_task, axis=1)

        analyse_group_df.buffer_size = analyse_group_df.buffer_size.apply(lambda x: 20000 if x == 25000 else x)
        # analyse_group_df = analyse_group_df.set_index(['controller', 'category', 'buffer_size'])

        pivot_table = pd.pivot_table(
            analyse_group_df.reset_index(), 
            columns=['controller', 'buffer_size', 'trained_task'],
            index=["category", "task_name"], 
            values="current_undiscounted_value", aggfunc="mean"
        )
        
        pivot_table = pivot_table.sort_index(key=experiment_sort_index, ascending=True).sort_index(key=experiment_sort_index, axis=1, ascending=True)
    else:
        pivot_table = None

    return pivot_table

pivot_avg(df[df.category == "LineFollowing"])
pivot_avg(df).to_latex()
# df.head()
# Out:
# Index(['LineFollowing', 'LineFollowing', 'LineFollowing', 'LineFollowing'], dtype='object', name='category')
# Index(['circle_blue', 'circle_green', 'circle_red', 'circle_yellow'], dtype='object', name='task_name')
# Index(['SAC', 'SAC', 'SAC', 'SAC'], dtype='object', name='controller')
# Index([20000, 20000, 20000, 20000], dtype='int64', name='buffer_size')
# Index(['circle_blue', 'circle_green', 'circle_red', 'circle_yellow'], dtype='object', name='trained_task')
# Index(['LineFollowing', 'LineFollowing', 'LineFollowing', 'LineFollowing'], dtype='object', name='category')
# Index(['circle_blue', 'circle_green', 'circle_red', 'circle_yellow'], dtype='object', name='task_name')
# Index(['SAC', 'SAC', 'SAC', 'SAC'], dtype='object', name='controller')
# Index([20000, 20000, 20000, 20000], dtype='int64', name='buffer_size')
# Index(['circle_blue', 'circle_green', 'circle_red', 'circle_yellow'], dtype='object', name='trained_task')
# '\\begin{tabular}{llrrrr}\n\\toprule\n & controller & \\multicolumn{4}{r}{SAC} \\\\\n & buffer_size & \\multicolumn{4}{r}{20000} \\\\\n & trained_task & circle_red & circle_blue & circle_green & circle_yellow \\\\\ncategory & task_name &  &  &  &  \\\\\n\\midrule\n\\multirow[t]{4}{*}{LineFollowing} & circle_red & 24.765986 & 26.289796 & 26.895238 & 26.680272 \\\\\n & circle_blue & NaN & 25.489796 & 26.843537 & 26.937415 \\\\\n & circle_green & NaN & NaN & 18.074830 & 26.297959 \\\\\n & circle_yellow & NaN & NaN & NaN & 27.295238 \\\\\n\\cline{1-6}\n\\bottomrule\n\\end{tabular}\n'

# %%
pivot_avg(df[df.category == "RobotPursuit"])
